# %%
from sunpycube.cube.datacube import Cube
from sunpycube.wcs_util import WCS
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.units as u
raster_file = "/home/ankit/Desktop/DATA/STEVE/iris_l2_20141211_191222_3803105278_raster_t000_r00000.fits"
hdulist = fits.open(raster_file)
w = WCS(header=hdulist[1].header)
dc = Cube(hdulist[1].data, w)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
ax.imshow(dc.data[0, :, :], cmap=plt.cm.gist_heat, origin='lower')
plt.show()
# Out:
# WARNING: AstropyDeprecationWarning: astropy.utils.compat.odict.OrderedDict is now deprecated - import OrderedDict from the collections module instead [astropy.utils.compat.odict]

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
# ax.coords[2].set_axislabel("hello")
#changing the unit of x axis in next line
ax.coords[2].set_format_unit(u.nm)
#next line is not working 
# ax.coords[2].set_major_formatter('x.x')
ax.imshow(dc.data[0, :, :], cmap=plt.cm.gist_heat, origin='lower')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=('x', 0,  'y'))
ax.coords[2].set_ticks(exclude_overlapping=True)
# ax.coords[2].set_format_unit(u.nm)
ax.imshow(dc.data[:, 0, :], cmap=plt.cm.gist_heat, origin='lower')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=('x', 'y', 0))
ax.coords[2].set_ticks(exclude_overlapping=True)
# ax.coords[2].set_format_unit(u.nm)
ax.imshow(dc.data[:, :, 0], cmap=plt.cm.gist_heat, origin='lower')
plt.show()
# Out:
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/astropy/visualization/wcsaxes/utils.py:88: RuntimeWarning: divide by zero encountered in log10
#   log10_dv = np.log10(dv)
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/astropy/visualization/wcsaxes/utils.py:91: RuntimeWarning: invalid value encountered in double_scalars
#   frac = log10_dv - base
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/astropy/visualization/wcsaxes/formatter_locator.py:97: RuntimeWarning: divide by zero encountered in double_scalars
#   imin = np.ceil(value_min / spacing)
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/astropy/visualization/wcsaxes/formatter_locator.py:98: RuntimeWarning: divide by zero encountered in double_scalars
#   imax = np.floor(value_max / spacing)
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/astropy/visualization/wcsaxes/formatter_locator.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   values = np.arange(imin, imax + 1, dtype=int)

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
# ax.coords[2].set_axislabel("hello")
#changing the unit of x axis in next line
ax.coords[2].set_format_unit(u.nm)
#next line is not working 
ax.coords[2].set_major_formatter('x.xxxx')
ax.imshow(dc.data[0, :, :], cmap=plt.cm.gist_heat, origin='lower')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
# ax.coords[2].set_axislabel("hello")
#changing the unit of x axis in next line
ax.coords[2].set_format_unit(u.nm)
#next line is not working 
ax.coords[2].set_major_formatter('%.2f')
ax.imshow(dc.data[0, :, :], cmap=plt.cm.gist_heat, origin='lower')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
# ax.coords[2].set_axislabel("hello")
#changing the unit of x axis in next line
ax.coords[2].set_format_unit(u.nm)
#next line is not working 
ax.coords[2].set_major_formatter('%.10f')
ax.imshow(dc.data[0, :, :], cmap=plt.cm.gist_heat, origin='lower')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()


def f(x, y):
    return np.sin(x) + np.cos(y)


ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = plt.imshow(f(x, y), animated=True)
    ims.append([im])

anim = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
ax.coords[2].set_format_unit(u.nm)

# data = dc.data[0]
# im = plt.imshow(data, animated=True)


ims = []
for i in range(dc.data.shape[0]):
#     x += np.pi / 15.
#     y += np.pi / 20.
    im = plt.imshow(dc.data[i], cmap=plt.cm.gist_heat, origin='lower', animated=True)
    ims.append([im])
    
anim = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)
#plt.show()
# call the animator. blit=True means only re-draw the parts that have changed.
#anim = animation.FuncAnimation(fig, animate, init_func=init,
#                               frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection=dc.axes_wcs, slices=(0, 'y',  'x'))
ax.coords[2].set_ticks(exclude_overlapping=True)
ax.coords[2].set_format_unit(u.nm)

# data = dc.data[0]
# im = plt.imshow(data,cmap=plt.cm.gist_heat, origin='lower', animated=True)


def updatefig(i):
    print(i)
    global data
#     if i==8:
#         return im,
    data = dc.data[i]
    im.set_array(data)
    print("end", i)
    return im,

anim = animation.FuncAnimation(fig, updatefig, interval=50, blit=True)

HTML(anim.to_html5_video())
# Out:
# 0
# ('end', 0)
# 0
# ('end', 0)
# 0
# ('end', 0)
# 1
# ('end', 1)
# 2
# ('end', 2)
# 3
# ('end', 3)
# 4
# ('end', 4)
# 5
# ('end', 5)
# 6
# ('end', 6)
# 7
# ('end', 7)
# 8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-50c0f12d9d70> in <module>()
#      24 anim = animation.FuncAnimation(fig, updatefig, interval=50, blit=True)
#      25
# ---> 26 HTML(anim.to_html5_video())
#
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/matplotlib/animation.pyc in to_html5_video(self)
#    1157                                 bitrate=rcParams['animation.bitrate'],
#    1158                                 fps=1000. / self._interval)
# -> 1159                 self.save(f.name, writer=writer)
#    1160
#    1161             # Now open and base64 encode
#
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1010                     for anim, d in zip(all_anim, data):
#    1011                         # TODO: See if turning off blit is really necessary
# -> 1012                         anim._draw_next_frame(d, blit=False)
#    1013                     writer.grab_frame(**savefig_kwargs)
#    1014
#
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_next_frame(self, framedata, blit)
#    1047         # post- draw, as well as the drawing of the frame itself.
#    1048         self._pre_draw(framedata, blit)
# -> 1049         self._draw_frame(framedata)
#    1050         self._post_draw(framedata, blit)
#    1051
#
# /home/ankit/workspace/IRISPY/iris/local/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_frame(self, framedata)
#    1510         # Call the func with framedata and args. If blitting is desired,
#    1511         # func needs to return a sequence of any artists that were modified.
# -> 1512         self._drawn_artists = self._func(framedata, *self._args)
#    1513         if self._blit:
#    1514             if self._drawn_artists is None:
#
# <ipython-input-36-50c0f12d9d70> in updatefig(i)
#      17 #     if i==8:
#      18 #         return im,
# ---> 19     data = dc.data[i]
#      20     im.set_array(data)
#      21     print("end", i)
#
# IndexError: index 8 is out of bounds for axis 0 with size 8
